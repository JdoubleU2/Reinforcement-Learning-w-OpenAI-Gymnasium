# %% [markdown]
#  #### Install necessary dependacies

# %%
# !pip install stable_baselines3
# !pip install "gymnasium[mujoco]"
# Out:
# Requirement already satisfied: stable_baselines3 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (2.7.0)
# Requirement already satisfied: gymnasium<1.3.0,>=0.29.1 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from stable_baselines3) (1.2.2)
# Requirement already satisfied: numpy<3.0,>=1.20 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from stable_baselines3) (2.2.6)
# Requirement already satisfied: torch<3.0,>=2.3 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from stable_baselines3) (2.9.0)
# Requirement already satisfied: cloudpickle in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from stable_baselines3) (3.1.2)
# Requirement already satisfied: pandas in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from stable_baselines3) (2.3.3)
# Requirement already satisfied: matplotlib in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from stable_baselines3) (3.10.7)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from gymnasium<1.3.0,>=0.29.1->stable_baselines3) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from gymnasium<1.3.0,>=0.29.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: filelock in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (3.20.0)
# Requirement already satisfied: setuptools in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (3.5)
# Requirement already satisfied: jinja2 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (2025.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable_baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from jinja2->torch<3.0,>=2.3->stable_baselines3) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from matplotlib->stable_baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from matplotlib->stable_baselines3) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from matplotlib->stable_baselines3) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from matplotlib->stable_baselines3) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from matplotlib->stable_baselines3) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from matplotlib->stable_baselines3) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from matplotlib->stable_baselines3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from pandas->stable_baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from pandas->stable_baselines3) (2025.2)
# Requirement already satisfied: gymnasium[mujoco] in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from gymnasium[mujoco]) (2.2.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from gymnasium[mujoco]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from gymnasium[mujoco]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from gymnasium[mujoco]) (0.0.4)
# Collecting mujoco>=2.1.5 (from gymnasium[mujoco])
#   Downloading mujoco-3.3.7-cp312-cp312-macosx_11_0_arm64.whl.metadata (41 kB)
# Requirement already satisfied: imageio>=2.14.1 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from gymnasium[mujoco]) (2.37.2)
# Requirement already satisfied: packaging>=23.0 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from gymnasium[mujoco]) (25.0)
# Requirement already satisfied: pillow>=8.3.2 in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from imageio>=2.14.1->gymnasium[mujoco]) (11.3.0)
# Requirement already satisfied: absl-py in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from mujoco>=2.1.5->gymnasium[mujoco]) (2.3.1)
# Collecting etils[epath] (from mujoco>=2.1.5->gymnasium[mujoco])
#   Downloading etils-1.13.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting glfw (from mujoco>=2.1.5->gymnasium[mujoco])
#   Downloading glfw-2.10.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-macosx_11_0_arm64.whl.metadata (5.4 kB)
# Collecting pyopengl (from mujoco>=2.1.5->gymnasium[mujoco])
#   Downloading pyopengl-3.1.10-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: fsspec in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[mujoco]) (2025.10.0)
# Collecting importlib_resources (from etils[epath]->mujoco>=2.1.5->gymnasium[mujoco])
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: zipp in /Users/jabinwade/miniconda3/envs/RLTraining/lib/python3.12/site-packages (from etils[epath]->mujoco>=2.1.5->gymnasium[mujoco]) (3.23.0)
# Downloading mujoco-3.3.7-cp312-cp312-macosx_11_0_arm64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 18.5 MB/s  0:00:00 eta 0:00:01
# Downloading etils-1.13.0-py3-none-any.whl (170 kB)
# Downloading glfw-2.10.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-macosx_11_0_arm64.whl (102 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading pyopengl-3.1.10-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 21.5 MB/s  0:00:00
# Installing collected packages: pyopengl, glfw, importlib_resources, etils, mujoco
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [mujoco]2m4/5 [mujoco]
# Successfully installed etils-1.13.0 glfw-2.10.0 importlib_resources-6.5.2 mujoco-3.3.7 pyopengl-3.1.10

# %%
import gymnasium as gym
from stable_baselines3 import PPO
import os
os.environ["MUJOCO_GL"] = "egl"

# %% [markdown]
# #### Create environment and train model

# %%
env_name = "Ant-v5"
env = gym.make(env_name, render_mode = "rgb_array")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 2
#       1 env_name = "Ant-v5"
# ----> 2 env = gym.make(env_name, render_mode = "rgb_array")
#
# File ~/miniconda3/envs/RLTraining/lib/python3.12/site-packages/gymnasium/envs/registration.py:696, in make(id, max_episode_steps, disable_env_checker, **kwargs)
#     693     env_creator = env_spec.entry_point
#     694 else:
#     695     # Assume it's a string
# --> 696     env_creator = load_env_creator(env_spec.entry_point)
#     698 # Determine if to use the rendering
#     699 render_modes: list[str] | None = None
#
# File ~/miniconda3/envs/RLTraining/lib/python3.12/site-packages/gymnasium/envs/registration.py:544, in load_env_creator(name)
#     535 """Loads an environment with name of style ``"(import path):(environment name)"`` and returns the environment creation function, normally the environment class type.
#     536
#     537 Args:
#    (...)    541     The environment constructor for the given environment name.
#     542 """
#     543 mod_name, attr_name = name.split(":")
# --> 544 mod = importlib.import_module(mod_name)
#     545 fn = getattr(mod, attr_name)
#     546 return fn
#
# File ~/miniconda3/envs/RLTraining/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1310, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:999, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/miniconda3/envs/RLTraining/lib/python3.12/site-packages/gymnasium/envs/mujoco/__init__.py:1
# ----> 1 from gymnasium.envs.mujoco.mujoco_env import MujocoEnv
#       2 from gymnasium.envs.mujoco.mujoco_rendering import MujocoRenderer
#
# File ~/miniconda3/envs/RLTraining/lib/python3.12/site-packages/gymnasium/envs/mujoco/mujoco_env.py:12
#       8 from gymnasium.spaces import Space
#      11 try:
# ---> 12     import mujoco
#      13 except ImportError as e:
#      14     raise error.DependencyNotInstalled(
#      15         'MuJoCo is not installed, run `pip install "gymnasium[mujoco]"`'
#      16     ) from e
#
# File ~/miniconda3/envs/RLTraining/lib/python3.12/site-packages/mujoco/__init__.py:62
#      60 from mujoco._specs import *
#      61 from mujoco._structs import *
# ---> 62 from mujoco.gl_context import *
#      63 from mujoco.renderer import Renderer
#      65 MjStruct: TypeAlias = Union[
#      66     _specs.MjsBody,
#      67     _specs.MjsFrame,
#    (...)     89     _specs.MjsPlugin,
#      90 ]
#
# File ~/miniconda3/envs/RLTraining/lib/python3.12/site-packages/mujoco/gl_context.py:34
#      32   _VALID_MUJOCO_GL += ('cgl',)
#      33 if _MUJOCO_GL not in _VALID_MUJOCO_GL:
# ---> 34   raise RuntimeError(
#      35       f'invalid value for environment variable MUJOCO_GL: {_MUJOCO_GL}')
#      37 if _SYSTEM == 'Linux' and _MUJOCO_GL == 'osmesa':
#      38   from mujoco.osmesa import GLContext as _GLContext
#
# RuntimeError: invalid value for environment variable MUJOCO_GL: egl

# %%
# %load_ext tensorboard
# %tensorboard --logdir ./Ant_tensorboard/

# %%
#Define model here

#train model here

model.save("model_Ant")

# %% [markdown]
# #### Valdiate model by having it interact with live MuJoCo environment

# %%
#Load model here

# %%
from gymnasium.wrappers import RecordVideo
import matplotlib.pyplot as plt
env_name = "Ant-v5"
env = gym.make(env_name, render_mode = "rgb_array")
env = RecordVideo(env, "./")

env_data = env.reset()
obs = env_data[0]

episode_reward = 0
#max_ep_timesteps = #define number of validation timesteps here

for t in range(max_ep_timesteps):
    print(f"timestep: {t}")

    action, _ = model.predict(obs)
    env_data = env.step(action)
    obs = env_data[0]
    reward = env_data[1]
    done = env_data[2]

    episode_reward += reward

    print(f"action: {action}")
    print(f"episode reward: {episode_reward}")
    print(env_data[1:])

    if done: break
env.close()
