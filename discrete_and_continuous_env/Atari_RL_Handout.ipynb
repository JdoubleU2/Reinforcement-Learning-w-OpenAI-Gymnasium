# %%
import gymnasium as gym
from stable_baselines3 import DQN
import ale_py

# %% [markdown]
# #### Check all registerd environemnts in Gymnasium

# %%
# List all registered envs
envs = gym.envs.registry.keys()

# Filter for Atari ones
atari_envs = [env_id for env_id in envs if "NoFrameskip" in env_id]
print(sorted(envs))
# Out:
# ['ALE/Adventure-v5', 'ALE/AirRaid-v5', 'ALE/Alien-v5', 'ALE/Amidar-v5', 'ALE/Assault-v5', 'ALE/Asterix-v5', 'ALE/Asteroids-v5', 'ALE/Atlantis-v5', 'ALE/Atlantis2-v5', 'ALE/Backgammon-v5', 'ALE/BankHeist-v5', 'ALE/BasicMath-v5', 'ALE/BattleZone-v5', 'ALE/BeamRider-v5', 'ALE/Berzerk-v5', 'ALE/Blackjack-v5', 'ALE/Bowling-v5', 'ALE/Boxing-v5', 'ALE/Breakout-v5', 'ALE/Carnival-v5', 'ALE/Casino-v5', 'ALE/Centipede-v5', 'ALE/ChopperCommand-v5', 'ALE/CrazyClimber-v5', 'ALE/Crossbow-v5', 'ALE/Darkchambers-v5', 'ALE/Defender-v5', 'ALE/DemonAttack-v5', 'ALE/DonkeyKong-v5', 'ALE/DoubleDunk-v5', 'ALE/Earthworld-v5', 'ALE/ElevatorAction-v5', 'ALE/Enduro-v5', 'ALE/Entombed-v5', 'ALE/Et-v5', 'ALE/FishingDerby-v5', 'ALE/FlagCapture-v5', 'ALE/Freeway-v5', 'ALE/Frogger-v5', 'ALE/Frostbite-v5', 'ALE/Galaxian-v5', 'ALE/Gopher-v5', 'ALE/Gravitar-v5', 'ALE/Hangman-v5', 'ALE/HauntedHouse-v5', 'ALE/Hero-v5', 'ALE/HumanCannonball-v5', 'ALE/IceHockey-v5', 'ALE/Jamesbond-v5', 'ALE/JourneyEscape-v5', 'ALE/Kaboom-v5', 'ALE/Kangaroo-v5', 'ALE/KeystoneKapers-v5', 'ALE/KingKong-v5', 'ALE/Klax-v5', 'ALE/Koolaid-v5', 'ALE/Krull-v5', 'ALE/KungFuMaster-v5', 'ALE/LaserGates-v5', 'ALE/LostLuggage-v5', 'ALE/MarioBros-v5', 'ALE/MiniatureGolf-v5', 'ALE/MontezumaRevenge-v5', 'ALE/MrDo-v5', 'ALE/MsPacman-v5', 'ALE/NameThisGame-v5', 'ALE/Othello-v5', 'ALE/Pacman-v5', 'ALE/Phoenix-v5', 'ALE/Pitfall-v5', 'ALE/Pitfall2-v5', 'ALE/Pong-v5', 'ALE/Pooyan-v5', 'ALE/PrivateEye-v5', 'ALE/Qbert-v5', 'ALE/Riverraid-v5', 'ALE/RoadRunner-v5', 'ALE/Robotank-v5', 'ALE/Seaquest-v5', 'ALE/SirLancelot-v5', 'ALE/Skiing-v5', 'ALE/Solaris-v5', 'ALE/SpaceInvaders-v5', 'ALE/SpaceWar-v5', 'ALE/StarGunner-v5', 'ALE/Superman-v5', 'ALE/Surround-v5', 'ALE/Tennis-v5', 'ALE/Tetris-v5', 'ALE/TicTacToe3D-v5', 'ALE/TimePilot-v5', 'ALE/Trondead-v5', 'ALE/Turmoil-v5', 'ALE/Tutankham-v5', 'ALE/UpNDown-v5', 'ALE/Venture-v5', 'ALE/VideoCheckers-v5', 'ALE/VideoChess-v5', 'ALE/VideoCube-v5', 'ALE/VideoPinball-v5', 'ALE/WizardOfWor-v5', 'ALE/WordZapper-v5', 'ALE/YarsRevenge-v5', 'ALE/Zaxxon-v5', 'Acrobot-v1', 'Adventure-v0', 'Adventure-v4', 'AdventureNoFrameskip-v0', 'AdventureNoFrameskip-v4', 'AirRaid-v0', 'AirRaid-v4', 'AirRaidNoFrameskip-v0', 'AirRaidNoFrameskip-v4', 'Alien-v0', 'Alien-v4', 'AlienNoFrameskip-v0', 'AlienNoFrameskip-v4', 'Amidar-v0', 'Amidar-v4', 'AmidarNoFrameskip-v0', 'AmidarNoFrameskip-v4', 'Ant-v2', 'Ant-v3', 'Ant-v4', 'Ant-v5', 'Assault-v0', 'Assault-v4', 'AssaultNoFrameskip-v0', 'AssaultNoFrameskip-v4', 'Asterix-v0', 'Asterix-v4', 'AsterixNoFrameskip-v0', 'AsterixNoFrameskip-v4', 'Asteroids-v0', 'Asteroids-v4', 'AsteroidsNoFrameskip-v0', 'AsteroidsNoFrameskip-v4', 'Atlantis-v0', 'Atlantis-v4', 'AtlantisNoFrameskip-v0', 'AtlantisNoFrameskip-v4', 'BankHeist-v0', 'BankHeist-v4', 'BankHeistNoFrameskip-v0', 'BankHeistNoFrameskip-v4', 'BattleZone-v0', 'BattleZone-v4', 'BattleZoneNoFrameskip-v0', 'BattleZoneNoFrameskip-v4', 'BeamRider-v0', 'BeamRider-v4', 'BeamRiderNoFrameskip-v0', 'BeamRiderNoFrameskip-v4', 'Berzerk-v0', 'Berzerk-v4', 'BerzerkNoFrameskip-v0', 'BerzerkNoFrameskip-v4', 'BipedalWalker-v3', 'BipedalWalkerHardcore-v3', 'Blackjack-v1', 'Bowling-v0', 'Bowling-v4', 'BowlingNoFrameskip-v0', 'BowlingNoFrameskip-v4', 'Boxing-v0', 'Boxing-v4', 'BoxingNoFrameskip-v0', 'BoxingNoFrameskip-v4', 'Breakout-v0', 'Breakout-v4', 'BreakoutNoFrameskip-v0', 'BreakoutNoFrameskip-v4', 'CarRacing-v3', 'Carnival-v0', 'Carnival-v4', 'CarnivalNoFrameskip-v0', 'CarnivalNoFrameskip-v4', 'CartPole-v0', 'CartPole-v1', 'Centipede-v0', 'Centipede-v4', 'CentipedeNoFrameskip-v0', 'CentipedeNoFrameskip-v4', 'ChopperCommand-v0', 'ChopperCommand-v4', 'ChopperCommandNoFrameskip-v0', 'ChopperCommandNoFrameskip-v4', 'CliffWalking-v1', 'CliffWalkingSlippery-v1', 'CrazyClimber-v0', 'CrazyClimber-v4', 'CrazyClimberNoFrameskip-v0', 'CrazyClimberNoFrameskip-v4', 'Defender-v0', 'Defender-v4', 'DefenderNoFrameskip-v0', 'DefenderNoFrameskip-v4', 'DemonAttack-v0', 'DemonAttack-v4', 'DemonAttackNoFrameskip-v0', 'DemonAttackNoFrame ...

# %% [markdown]
# #### If Atari Environment not registedred run code below

# %%
gym.register_envs(ale_py)

# %% [markdown]
# #### Create environment and train model

# %%
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack
env_name = "FreewayNoFrameskip-v4"
env = make_atari_env(env_name, n_envs=4, seed=0)
env = VecFrameStack(env, n_stack=4)
# Out:
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]

# %%
# %load_ext tensorboard
# %tensorboard --logdir ./freeway_tensorboard/
# Out:
# Reusing TensorBoard on port 6006 (pid 83319), started 1:09:40 ago. (Use '!kill 83319' to kill it.)
#       <iframe id="tensorboard-frame-4d9f93714bb7d353" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-4d9f93714bb7d353");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
#Define model here

model = DQN(
    'CnnPolicy',
    env,
    verbose=1,
    learning_rate=0.00025,
    gamma=0.99,
    buffer_size=100000,
    batch_size=32,
    train_freq=4,
    target_update_interval=10000,
    learning_starts=50000,
    exploration_fraction=0.1,
    exploration_final_eps=0.01,
    tensorboard_log="./freeway_tensorboard"
)


#train model here
model.learn(total_timesteps=1000000)

model.save("model_Freeway")
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# Logging to ./freeway_tensorboard/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1752     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 8188     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1828     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 16364    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.757    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1857     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 24556    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.676    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1871     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 32720    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.595    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1879     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 40904    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.514    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1884     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 49084    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.433    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1297     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 57264    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 4.92e-08 |
# |    n_updates        | 453      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.352    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1021     |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 65452    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 2.04e-07 |
# |    n_updates        | 965      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.271    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 877      |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 73640    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.76e-07 |
# |    n_updates        | 1477     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 0.025    |
# |    exploration_rate | 0.19     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 784      |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 81824    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 5.09e-09 |
# |    n_updates        | 1988     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 0.0227   |
# |    exploration_rate | 0.109    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 725      |
# |    time_elapsed     | 124      |
# |    total_timesteps  | 89988    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.37e-08 |
# |    n_updates        | 2499     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 0.0208   |
# |    exploration_rate | 0.0283   |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 682      |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 98152    |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.28e-08 |
# |    n_updates        | 3009     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 0.0192   |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 649      |
# |    time_elapsed     | 163      |
# |    total_timesteps  | 106336   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.07e-08 |
# |    n_updates        | 3520     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 0.0714   |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 623      |
# |    time_elapsed     | 183      |
# |    total_timesteps  | 114520   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 7.83e-09 |
# |    n_updates        | 4032     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 0.0667   |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 603      |
# |    time_elapsed     | 203      |
# |    total_timesteps  | 122704   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.75e-08 |
# |    n_updates        | 4543     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 0.0938   |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 584      |
# |    time_elapsed     | 223      |
# |    total_timesteps  | 130880   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 2.12e-08 |
# |    n_updates        | 5054     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 0.0882   |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 571      |
# |    time_elapsed     | 243      |
# |    total_timesteps  | 139048   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.58e-08 |
# |    n_updates        | 5565     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 0.569    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 560      |
# |    time_elapsed     | 262      |
# |    total_timesteps  | 147236   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 5.63e-07 |
# |    n_updates        | 6077     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 0.842    |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 550      |
# |    time_elapsed     | 282      |
# |    total_timesteps  | 155412   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 2.82e-06 |
# |    n_updates        | 6588     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 1.36     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 542      |
# |    time_elapsed     | 301      |
# |    total_timesteps  | 163588   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 9.49e-08 |
# |    n_updates        | 7099     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 2.05     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 534      |
# |    time_elapsed     | 321      |
# |    total_timesteps  | 171768   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.96e-06 |
# |    n_updates        | 7610     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 2.82     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 527      |
# |    time_elapsed     | 341      |
# |    total_timesteps  | 179944   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 2.12e-06 |
# |    n_updates        | 8121     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 3.64     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 521      |
# |    time_elapsed     | 360      |
# |    total_timesteps  | 188116   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.49e-05 |
# |    n_updates        | 8632     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 4.45     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 516      |
# |    time_elapsed     | 380      |
# |    total_timesteps  | 196300   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0154   |
# |    n_updates        | 9143     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 5.11     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 511      |
# |    time_elapsed     | 399      |
# |    total_timesteps  | 204480   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 7.36e-06 |
# |    n_updates        | 9654     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 6        |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 507      |
# |    time_elapsed     | 418      |
# |    total_timesteps  | 212664   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0154   |
# |    n_updates        | 10166    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 6.98     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 503      |
# |    time_elapsed     | 438      |
# |    total_timesteps  | 220856   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0153   |
# |    n_updates        | 10678    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 7.92     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 500      |
# |    time_elapsed     | 458      |
# |    total_timesteps  | 229048   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0156   |
# |    n_updates        | 11190    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 8.73     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 495      |
# |    time_elapsed     | 478      |
# |    total_timesteps  | 237228   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0152   |
# |    n_updates        | 11701    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 9.62     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 492      |
# |    time_elapsed     | 497      |
# |    total_timesteps  | 245404   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 8.47e-05 |
# |    n_updates        | 12212    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 490      |
# |    time_elapsed     | 517      |
# |    total_timesteps  | 253588   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.000174 |
# |    n_updates        | 12724    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 11.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 486      |
# |    time_elapsed     | 537      |
# |    total_timesteps  | 261756   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 5.86e-05 |
# |    n_updates        | 13234    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 12.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 483      |
# |    time_elapsed     | 558      |
# |    total_timesteps  | 269924   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0154   |
# |    n_updates        | 13745    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 13.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 481      |
# |    time_elapsed     | 577      |
# |    total_timesteps  | 278112   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 6.45e-08 |
# |    n_updates        | 14256    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 14       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 479      |
# |    time_elapsed     | 596      |
# |    total_timesteps  | 286284   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 4.32e-05 |
# |    n_updates        | 14767    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 477      |
# |    time_elapsed     | 616      |
# |    total_timesteps  | 294472   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 3.17e-05 |
# |    n_updates        | 15279    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 15.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 471      |
# |    time_elapsed     | 642      |
# |    total_timesteps  | 302644   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 6.32e-05 |
# |    n_updates        | 15790    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 16.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 468      |
# |    time_elapsed     | 663      |
# |    total_timesteps  | 310808   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0155   |
# |    n_updates        | 16300    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 17.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 465      |
# |    time_elapsed     | 685      |
# |    total_timesteps  | 318980   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0154   |
# |    n_updates        | 16811    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 18.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 462      |
# |    time_elapsed     | 707      |
# |    total_timesteps  | 327164   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.000112 |
# |    n_updates        | 17322    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 19.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 460      |
# |    time_elapsed     | 728      |
# |    total_timesteps  | 335344   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 3.84e-05 |
# |    n_updates        | 17833    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 20       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 456      |
# |    time_elapsed     | 753      |
# |    total_timesteps  | 343516   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 4.49e-05 |
# |    n_updates        | 18344    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 451      |
# |    time_elapsed     | 779      |
# |    total_timesteps  | 351700   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 9.26e-05 |
# |    n_updates        | 18856    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 446      |
# |    time_elapsed     | 805      |
# |    total_timesteps  | 359868   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 6.98e-05 |
# |    n_updates        | 19366    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 442      |
# |    time_elapsed     | 831      |
# |    total_timesteps  | 368052   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.000127 |
# |    n_updates        | 19878    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 438      |
# |    time_elapsed     | 857      |
# |    total_timesteps  | 376240   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0307   |
# |    n_updates        | 20389    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 434      |
# |    time_elapsed     | 884      |
# |    total_timesteps  | 384408   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0154   |
# |    n_updates        | 20900    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 431      |
# |    time_elapsed     | 909      |
# |    total_timesteps  | 392588   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0154   |
# |    n_updates        | 21411    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 428      |
# |    time_elapsed     | 934      |
# |    total_timesteps  | 400772   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 2.38e-05 |
# |    n_updates        | 21923    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 424      |
# |    time_elapsed     | 962      |
# |    total_timesteps  | 408960   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0153   |
# |    n_updates        | 22434    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 421      |
# |    time_elapsed     | 989      |
# |    total_timesteps  | 417124   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.27e-05 |
# |    n_updates        | 22945    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 418      |
# |    time_elapsed     | 1015     |
# |    total_timesteps  | 425308   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0157   |
# |    n_updates        | 23456    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 416      |
# |    time_elapsed     | 1041     |
# |    total_timesteps  | 433480   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 3.93e-05 |
# |    n_updates        | 23967    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 414      |
# |    time_elapsed     | 1065     |
# |    total_timesteps  | 441664   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 7.8e-05  |
# |    n_updates        | 24478    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 412      |
# |    time_elapsed     | 1091     |
# |    total_timesteps  | 449840   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 3.07e-05 |
# |    n_updates        | 24989    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 409      |
# |    time_elapsed     | 1117     |
# |    total_timesteps  | 458004   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0153   |
# |    n_updates        | 25500    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 408      |
# |    time_elapsed     | 1142     |
# |    total_timesteps  | 466192   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.031    |
# |    n_updates        | 26011    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 406      |
# |    time_elapsed     | 1167     |
# |    total_timesteps  | 474380   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.00012  |
# |    n_updates        | 26523    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 404      |
# |    time_elapsed     | 1194     |
# |    total_timesteps  | 482572   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 7.08e-05 |
# |    n_updates        | 27035    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 403      |
# |    time_elapsed     | 1217     |
# |    total_timesteps  | 490764   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.000206 |
# |    n_updates        | 27547    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 401      |
# |    time_elapsed     | 1243     |
# |    total_timesteps  | 498940   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 2.96e-05 |
# |    n_updates        | 28058    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 399      |
# |    time_elapsed     | 1269     |
# |    total_timesteps  | 507108   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 4.23e-05 |
# |    n_updates        | 28569    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 397      |
# |    time_elapsed     | 1294     |
# |    total_timesteps  | 515288   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 3.61e-05 |
# |    n_updates        | 29080    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 396      |
# |    time_elapsed     | 1319     |
# |    total_timesteps  | 523472   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 7.39e-05 |
# |    n_updates        | 29591    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 395      |
# |    time_elapsed     | 1345     |
# |    total_timesteps  | 531648   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 4.91e-05 |
# |    n_updates        | 30102    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 394      |
# |    time_elapsed     | 1369     |
# |    total_timesteps  | 539820   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 8.34e-05 |
# |    n_updates        | 30613    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 392      |
# |    time_elapsed     | 1395     |
# |    total_timesteps  | 547988   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.26e-05 |
# |    n_updates        | 31124    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 391      |
# |    time_elapsed     | 1420     |
# |    total_timesteps  | 556180   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 2.97e-05 |
# |    n_updates        | 31636    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 390      |
# |    time_elapsed     | 1444     |
# |    total_timesteps  | 564348   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.15e-05 |
# |    n_updates        | 32146    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 389      |
# |    time_elapsed     | 1471     |
# |    total_timesteps  | 572528   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0153   |
# |    n_updates        | 32657    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 387      |
# |    time_elapsed     | 1496     |
# |    total_timesteps  | 580696   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 5.31e-05 |
# |    n_updates        | 33168    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 387      |
# |    time_elapsed     | 1521     |
# |    total_timesteps  | 588860   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 9.81e-06 |
# |    n_updates        | 33678    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 386      |
# |    time_elapsed     | 1546     |
# |    total_timesteps  | 597044   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0154   |
# |    n_updates        | 34190    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 384      |
# |    time_elapsed     | 1574     |
# |    total_timesteps  | 605208   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0153   |
# |    n_updates        | 34700    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 383      |
# |    time_elapsed     | 1601     |
# |    total_timesteps  | 613388   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 6.57e-05 |
# |    n_updates        | 35211    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 382      |
# |    time_elapsed     | 1626     |
# |    total_timesteps  | 621580   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.031    |
# |    n_updates        | 35723    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 381      |
# |    time_elapsed     | 1651     |
# |    total_timesteps  | 629752   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0306   |
# |    n_updates        | 36234    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 380      |
# |    time_elapsed     | 1676     |
# |    total_timesteps  | 637928   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 4.36e-05 |
# |    n_updates        | 36745    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 379      |
# |    time_elapsed     | 1703     |
# |    total_timesteps  | 646104   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 9.24e-05 |
# |    n_updates        | 37256    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 378      |
# |    time_elapsed     | 1728     |
# |    total_timesteps  | 654284   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0306   |
# |    n_updates        | 37767    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 377      |
# |    time_elapsed     | 1754     |
# |    total_timesteps  | 662448   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0154   |
# |    n_updates        | 38277    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 376      |
# |    time_elapsed     | 1781     |
# |    total_timesteps  | 670612   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 2.89e-05 |
# |    n_updates        | 38788    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 375      |
# |    time_elapsed     | 1806     |
# |    total_timesteps  | 678792   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 3.18e-05 |
# |    n_updates        | 39299    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 374      |
# |    time_elapsed     | 1833     |
# |    total_timesteps  | 686972   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 2.26e-07 |
# |    n_updates        | 39810    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 373      |
# |    time_elapsed     | 1860     |
# |    total_timesteps  | 695160   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0151   |
# |    n_updates        | 40322    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 373      |
# |    time_elapsed     | 1885     |
# |    total_timesteps  | 703344   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 4.83e-05 |
# |    n_updates        | 40833    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 372      |
# |    time_elapsed     | 1910     |
# |    total_timesteps  | 711520   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0154   |
# |    n_updates        | 41344    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 371      |
# |    time_elapsed     | 1936     |
# |    total_timesteps  | 719684   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.000109 |
# |    n_updates        | 41855    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 371      |
# |    time_elapsed     | 1961     |
# |    total_timesteps  | 727864   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 5e-05    |
# |    n_updates        | 42366    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 370      |
# |    time_elapsed     | 1987     |
# |    total_timesteps  | 736036   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0153   |
# |    n_updates        | 42877    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 369      |
# |    time_elapsed     | 2012     |
# |    total_timesteps  | 744212   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 8.84e-05 |
# |    n_updates        | 43388    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 369      |
# |    time_elapsed     | 2037     |
# |    total_timesteps  | 752396   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 6.24e-06 |
# |    n_updates        | 43899    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 368      |
# |    time_elapsed     | 2062     |
# |    total_timesteps  | 760560   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.61e-05 |
# |    n_updates        | 44409    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 368      |
# |    time_elapsed     | 2087     |
# |    total_timesteps  | 768752   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 8e-05    |
# |    n_updates        | 44921    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 367      |
# |    time_elapsed     | 2114     |
# |    total_timesteps  | 776924   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.000127 |
# |    n_updates        | 45432    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 367      |
# |    time_elapsed     | 2138     |
# |    total_timesteps  | 785100   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.000252 |
# |    n_updates        | 45943    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 366      |
# |    time_elapsed     | 2165     |
# |    total_timesteps  | 793288   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0154   |
# |    n_updates        | 46455    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 365      |
# |    time_elapsed     | 2192     |
# |    total_timesteps  | 801452   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.000107 |
# |    n_updates        | 46965    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 364      |
# |    time_elapsed     | 2219     |
# |    total_timesteps  | 809628   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.000162 |
# |    n_updates        | 47476    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 364      |
# |    time_elapsed     | 2244     |
# |    total_timesteps  | 817812   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 3.59e-05 |
# |    n_updates        | 47988    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 363      |
# |    time_elapsed     | 2270     |
# |    total_timesteps  | 825988   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.000133 |
# |    n_updates        | 48499    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 363      |
# |    time_elapsed     | 2297     |
# |    total_timesteps  | 834180   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.000109 |
# |    n_updates        | 49011    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 362      |
# |    time_elapsed     | 2321     |
# |    total_timesteps  | 842372   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 5.83e-05 |
# |    n_updates        | 49523    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 361      |
# |    time_elapsed     | 2350     |
# |    total_timesteps  | 850540   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 3.8e-05  |
# |    n_updates        | 50033    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 361      |
# |    time_elapsed     | 2375     |
# |    total_timesteps  | 858724   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 2.65e-05 |
# |    n_updates        | 50545    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 361      |
# |    time_elapsed     | 2400     |
# |    total_timesteps  | 866912   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 4.46e-05 |
# |    n_updates        | 51056    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 360      |
# |    time_elapsed     | 2426     |
# |    total_timesteps  | 875088   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 5.33e-05 |
# |    n_updates        | 51567    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 360      |
# |    time_elapsed     | 2452     |
# |    total_timesteps  | 883264   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 4.26e-06 |
# |    n_updates        | 52078    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 359      |
# |    time_elapsed     | 2477     |
# |    total_timesteps  | 891456   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.77e-06 |
# |    n_updates        | 52590    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 359      |
# |    time_elapsed     | 2502     |
# |    total_timesteps  | 899632   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0305   |
# |    n_updates        | 53101    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 359      |
# |    time_elapsed     | 2527     |
# |    total_timesteps  | 907824   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 9.55e-06 |
# |    n_updates        | 53613    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 358      |
# |    time_elapsed     | 2554     |
# |    total_timesteps  | 916004   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0153   |
# |    n_updates        | 54125    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 358      |
# |    time_elapsed     | 2579     |
# |    total_timesteps  | 924172   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 5.3e-05  |
# |    n_updates        | 54635    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 357      |
# |    time_elapsed     | 2604     |
# |    total_timesteps  | 932356   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.77e-05 |
# |    n_updates        | 55147    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 357      |
# |    time_elapsed     | 2631     |
# |    total_timesteps  | 940544   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 1.56e-05 |
# |    n_updates        | 55658    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 357      |
# |    time_elapsed     | 2657     |
# |    total_timesteps  | 948720   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 5.56e-05 |
# |    n_updates        | 56169    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 356      |
# |    time_elapsed     | 2681     |
# |    total_timesteps  | 956912   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 3.59e-05 |
# |    n_updates        | 56681    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 356      |
# |    time_elapsed     | 2707     |
# |    total_timesteps  | 965096   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0153   |
# |    n_updates        | 57193    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 355      |
# |    time_elapsed     | 2733     |
# |    total_timesteps  | 973272   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0153   |
# |    n_updates        | 57704    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 355      |
# |    time_elapsed     | 2758     |
# |    total_timesteps  | 981452   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.0154   |
# |    n_updates        | 58215    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 355      |
# |    time_elapsed     | 2783     |
# |    total_timesteps  | 989616   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 0.000137 |
# |    n_updates        | 58725    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19e+03 |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 355      |
# |    time_elapsed     | 2808     |
# |    total_timesteps  | 997804   |
# | train/              |          |
# |    learning_rate    | 0.00025  |
# |    loss             | 8.24e-05 |
# |    n_updates        | 59237    |
# ----------------------------------

# %% [markdown]
# #### Valdiate model by having it play live atari game

# %%
#Load model here
model.load("model_Freeway")

# %%
from gymnasium.wrappers import RecordVideo
import matplotlib.pyplot as plt

env = gym.make(env_name, render_mode="rgb_array")
env = gym.wrappers.AtariPreprocessing(env, grayscale_obs=True, screen_size=84, frame_skip=4, scale_obs=False)
env = gym.wrappers.FrameStackObservation(env, stack_size=4)
env = RecordVideo(env, "./")

env_data = env.reset()
obs = env_data[0] #observation

episode_reward = 0
max_ep_timesteps = 100000

for t in range(max_ep_timesteps):
    print(f"timestep: {t}")

    action, _states = model.predict(obs, deterministic = True) # inference the model given the current game data. 
    env_data = env.step(action) # update enviorment data with action from inferenced model 
    obs = env_data[0] #update obs with new enviorment data from agent action 
    reward = env_data[1] #update reward with new enviorment data from agent action 
    done = env_data[2] # update if episode is done with new viorment data from agent action

    episode_reward += reward

    plt.imshow(obs[-1], cmap = "gray")
    plt.show()

    print(f"action: {action}")
    print(f"episode reward: {episode_reward}")
    print(env_data[1:])


    if done: break
env.close()
